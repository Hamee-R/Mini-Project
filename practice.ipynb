# %%
print("=" * 40)
print("         PYTHON LEARNER PROFILE           ")
print("=" * 40)

full_name = input("enter your first name") , input("enter your last name"), input("enter your middle name")


print("Name","" * 14,":",full_name)

age = input("How old are you?")

print("Age","" * 17,":",age)

Country = input("What Country are you from:")

print("Country","" * 8,":",Country)

Level = input("What level are you currently?")

print("Level","" * 10,":",Level)

Focus_Area = input("What is your area of focus?")

print("Focus Area","" * 9 ,":",Focus_Area)


Goal = input("What do you aim to achieve?")

print("Goal","" * 10 ,":",Goal)

print("Python can be used for:")

python_uses = ["Web Development","DATA SCIENCE","Automation","Cybersecurity","Machine Learning"]

for use in python_uses:
    print("-", use)


print("\nGood luck,", first_name,"!","Your Python journey starts NOW.")

print("=" * 40)
# Out:
# ...
#          PYTHON LEARNER PROFILE
# ...
# Name  : Hameedat Raheem
# Age  : 22
# Country  : Nigeria
# Level  : Beginner
# Focus Area  : Data Science
# Goal  : Money
# Python can be used for:
# - Web Development
# - DATA SCIENCE
# - Automation
# - Cybersecurity
# - Machine Learning
# Good luck, Hameedat ! Your Python journey starts NOW.

# %%
==========================================
        PYTHON LEARNER PROFILE
==========================================
Name       : Amara Johnson
Age        : 22
Country    : Ghana
Level      : Beginner
Focus Area : Data Science
Goal       : Build a salary prediction model
------------------------------------------
Python can be used for:
  - Web Development
  - *** DATA SCIENCE *** (your choice!)
  - Automation
  - Cybersecurity
  - Machine Learning
------------------------------------------
Good luck, Amara! Your Python journey starts NOW.
==========================================
