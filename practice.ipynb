# %%
print("=" * 40)
print("         PYTHON LEARNER PROFILE           ")
print("=" * 40)
first_name = input("enter your first name")
full_name = first_name + " " + input("enter your last name")


print("Name"," " * 5,":",full_name)

age = input("How old are you?")

print("Age"," " * 6,":",age)

Country = input("What Country are you from:")

print("Country"," " * 2,":",Country)

Level = input("What level are you currently?")

print("Level"," " * 4,":",Level)

Focus_Area = input("What is your area of focus?")

print("Focus Area",":",Focus_Area)


Goal = input("What do you aim to achieve?")

print("Goal"," " * 5 ,":",Goal)

print("-" * 40)

print("Python can be used for:")

python_uses = ["Web Development","DATA SCIENCE","Automation","Cybersecurity","Machine Learning"]

for use in python_uses:
    print("-", use)

print("-" * 40)

print("Good luck,", first_name,"!","Your Python journey starts NOW.")

print("=" * 40)
# Out:
# ...
#          PYTHON LEARNER PROFILE
# ...
# Name       : Hameedat  Raheem
# Age        : 22
# Country    : NIGERIA
# Level      : Beginner
# Focus Area : D.S
# Goal       : Money
# ----------------------------------------
# Python can be used for:
# - Web Development
# - DATA SCIENCE
# - Automation
# - Cybersecurity
# - Machine Learning
# ----------------------------------------
#
# Good luck, Hameedat  ! Your Python journey starts NOW.
# ...
